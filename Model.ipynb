# %% [markdown]
# ## Identifying Entities in Healthcare Data

# %%
#Importing and installing required packages
# !pip install pycrf
# !pip install sklearn-crfsuite

import spacy
import sklearn_crfsuite 
from sklearn_crfsuite import metrics
import pandas as pd

model = spacy.load("en_core_web_sm")

import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: pycrf in c:\users\moham\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: sklearn-crfsuite in c:\users\moham\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\moham\anaconda3\lib\site-packages (from sklearn-crfsuite) (0.9.9)
# Requirement already satisfied: six in c:\users\moham\anaconda3\lib\site-packages (from sklearn-crfsuite) (1.16.0)
# Requirement already satisfied: tabulate in c:\users\moham\anaconda3\lib\site-packages (from sklearn-crfsuite) (0.8.10)
# Requirement already satisfied: tqdm>=2.0 in c:\users\moham\anaconda3\lib\site-packages (from sklearn-crfsuite) (4.65.0)
# Requirement already satisfied: colorama in c:\users\moham\anaconda3\lib\site-packages (from tqdm>=2.0->sklearn-crfsuite) (0.4.6)

# %%
#Intializing the data
with open('C:\\Users\\moham\\Downloads\\inputs\\train_sent', 'r') as train_sent_file:
  train_words = train_sent_file.readlines()

with open('C:\\Users\\moham\\Downloads\\inputs\\train_label', 'r') as train_labels_file:
  train_labels_by_word = train_labels_file.readlines()

with open('C:\\Users\\moham\\Downloads\\inputs\\test_sent', 'r') as test_sent_file:
  test_words = test_sent_file.readlines()

with open('C:\\Users\\moham\\Downloads\\inputs\\test_label', 'r') as test_labels_file:
  test_labels_by_word = test_labels_file.readlines()

# %%
#Checking the inputs
train_words
# Out:
# ['All\n',
#  'live\n',
#  'births\n',
#  '>\n',
#  'or\n',
#  '=\n',
#  '23\n',
#  'weeks\n',
#  'at\n',
#  'the\n',
#  'University\n',
#  'of\n',
#  'Vermont\n',
#  'in\n',
#  '1995\n',
#  '(\n',
#  'n\n',
#  '=\n',
#  '2395\n',
#  ')\n',
#  'were\n',
#  'retrospectively\n',
#  'analyzed\n',
#  'for\n',
#  'delivery\n',
#  'route\n',
#  ',\n',
#  'indication\n',
#  'for\n',
#  'cesarean\n',
#  ',\n',
#  'gestational\n',
#  'age\n',
#  ',\n',
#  'parity\n',
#  ',\n',
#  'and\n',
#  'practice\n',
#  'group\n',
#  '(\n',
#  'to\n',
#  'reflect\n',
#  'risk\n',
#  'status\n',
#  ')\n',
#  '\n',
#  'The\n',
#  'total\n',
#  'cesarean\n',
#  'rate\n',
#  'was\n',
#  '14.4\n',
#  '%\n',
#  '(\n',
#  '344\n',
#  'of\n',
#  '2395\n',
#  ')\n',
#  ',\n',
#  'and\n',
#  'the\n',
#  'primary\n',
#  'rate\n',
#  'was\n',
#  '11.4\n',
#  '%\n',
#  '(\n',
#  '244\n',
#  'of\n',
#  '2144\n',
#  ')\n',
#  '\n',
#  'Abnormal\n',
#  'presentation\n',
#  'was\n',
#  'the\n',
#  'most\n',
#  'common\n',
#  'indication\n',
#  '(\n',
#  '25.6\n',
#  '%\n',
#  ',\n',
#  '88\n',
#  'of\n',
#  '344\n',
#  ')\n',
#  '\n',
#  'The\n',
#  '``\n',
#  'corrected\n',
#  "''\n",
#  'cesarean\n',
#  'rate\n',
#  '(\n',
#  'maternal-fetal\n',
#  'medicine\n',
#  'and\n',
#  'transported\n',
#  'patients\n',
#  'excluded\n',
#  ')\n',
#  'was\n',
#  '12.4\n',
#  '%\n',
#  '(\n',
#  '273\n',
#  'of\n',
#  '2194\n',
#  ')\n',
#  ',\n',
#  'and\n',
#  'the\n',
#  '``\n',
#  'corrected\n',
#  "''\n",
#  'primary\n',
#  'rate\n',
#  'was\n',
#  '9.6\n',
#  '%\n',
#  '(\n',
#  '190\n',
#  'of\n',
#  '1975\n',
#  ')\n',
#  '\n',
#  'Arrest\n',
#  'of\n',
#  'dilation\n',
#  'was\n',
#  'the\n',
#  'most\n',
#  'common\n',
#  'indication\n',
#  'in\n',
#  'both\n',
#  '``\n',
#  'corrected\n',
#  "''\n",
#  'subgroups\n',
#  '(\n',
#  '23.4\n',
#  'and\n',
#  '24.6\n',
#  '%\n',
#  ',\n',
#  'respectively\n',
#  ')\n',
#  '\n',
#  'Cesarean\n',
#  'rates\n',
#  'at\n',
#  'tertiary\n',
#  'care\n',
#  'hospitals\n',
#  'should\n',
#  'be\n',
#  'compared\n',
#  'with\n',
#  'rates\n',
#  'at\n',
#  'community\n',
#  'hospitals\n',
#  'only\n',
#  'after\n',
#  'correcting\n',
#  'for\n',
#  'dissimilar\n',
#  'patient\n',
#  'groups\n',
#  'or\n',
#  'gestational\n',
#  'age\n',
#  '\n',
#  'In\n',
#  'the\n',
#  'third\n',
#  'trimester\n',
#  ',\n',
#  'the\n',
#  'amniotic\n',
#  'fluid\n',
#  'index\n',
#  '(\n',
#  'AFI\n',
#  ')\n',
#  'may\n',
#  'be\n',
#  'affected\n',
#  'by\n',
#  'maternal\n',
#  'fluid\n',
#  'status\n',
#  '\n',
#  'We\n',
#  'hypothesize\n',
#  'that\n',
#  'as\n',
#  'temperature\n',
#  'increases\n',
#  'there\n',
#  'would\n',
#  'be\n',
#  'a\n',
#  'concomitant\n',
#  'decrease\n',
#  'in\n',
#  'AFI\n',
#  '\n',
#  'From\n',
#  'June\n',
#  '11\n',
#  'to\n',
#  'August\n',
#  '16\n',
#  ',\n',
#  '1993\n',
#  ',\n',
#  'during\n',
#  'a\n',
#  'period\n',
#  'of\n',
#  'unusual\n',
#  'high\n',
#  'heat\n',
#  ',\n',
#  '42\n',
#  'women\n',
#  'with\n',
#  'singleton\n',
#  'pregnancies\n',
#  'between\n',
#  '27\n',
#  'and\n',
#  '40\n',
#  'weeks\n',
#  "'\n",
#  'gestation\n',
#  'undergoing\n',
#  'serial\n',
#  'antenatal\n',
#  'testing\n',
#  'had\n',
#  'AFI\n',
#  'determinations\n',
#  'recorded\n',
#  'at\n',
#  'least\n',
#  'weekly\n',
#  '\n',
#  'The\n',
#  'daily\n',
#  'high\n',
#  'ambient\n',
#  'temperature\n',
#  'in\n',
#  'our\n',
#  'urban\n',
#  'area\n',
#  'was\n',
#  'subsequently\n',
#  'obtained\n',
#  '\n',
#  'A\n',
#  '2-\n',
#  ',\n',
#  '3-\n',
#  ',\n',
#  'and\n',
#  '4-day\n',
#  'mean\n',
#  'temperature\n',
#  'prior\n',
#  'to\n',
#  'the\n',
#  'test\n',
#  'date\n',
#  'was\n',
#  'compared\n',
#  'to\n',
#  'AFI\n',
#  'using\n',
#  'a\n',
#  'Spearman-rank\n',
#  'Correlation\n',
#  '\n',
#  'This\n',
#  'relationship\n',
#  'should\n',
#  'be\n',
#  'taken\n',
#  'into\n',
#  'account\n',
#  'when\n',
#  'interpreting\n',
#  'the\n',
#  'AFI\n',
#  'as\n',
#  'a\n',
#  'measure\n',
#  'of\n',
#  'fetal\n',
#  'well-being\n',
#  '\n',
#  'The\n',
#  'study\n',
#  'population\n',
#  'included\n',
#  '84\n',
#  'women\n',
#  'with\n',
#  'gestational\n',
#  'diabetes\n',
#  ',\n',
#  'ascertained\n',
#  'by\n',
#  'universal\n',
#  'screening\n',
#  'of\n',
#  'all\n',
#  'women\n',
#  'attending\n',
#  'the\n',
#  'antenatal\n',
#  'clinic\n',
#  'of\n',
#  'the\n',
#  'Hadassah\n',
#  'Medical\n',
#  'Center\n',
#  ',\n',
#  'over\n',
#  'a\n',
#  '2-year\n',
#  'period\n',
#  '\n',
#  'The\n',
#  '60\n',
#  'women\n',
#  '(\n',
#  '71\n',
#  '%\n',
#  ')\n',
#  ',\n',
#  'who\n',
#  'initiated\n',
#  'treatment\n',
#  'before\n',
#  '34\n',
#  'completed\n',
#  'weeks\n',
#  ',\n',
#  'composed\n',
#  'the\n',
#  '``\n',
#  'early\n',
#  "''\n",
#  'group\n',
#  '\n',
#  'The\n',
#  '24\n',
#  'women\n',
#  '(\n',
#  '29\n',
#  '%\n',
#  ')\n',
#  ',\n',
#  'who\n',
#  'initiated\n',
#  'treatment\n',
#  'after\n',
#  'the\n',
#  '34th\n',
#  'week\n',
#  ',\n',
#  'composed\n',
#  'the\n',
#  '``\n',
#  'late\n',
#  "''\n",
#  'group\n',
#  '\n',
#  'All\n',
#  'patients\n',
#  'were\n',
#  'managed\n',
#  'by\n',
#  'an\n',
#  'intensified\n',
#  'protocol\n',
#  ',\n',
#  'including\n',
#  'stringent\n',
#  'glycemic\n',
#  'control\n',
#  '\n',
#  'Maternal\n',
#  'characteristics\n',
#  'were\n',
#  'similar\n',
#  'in\n',
#  'the\n',
#  'two\n',
#  'groups\n',
#  '\n',
#  'No\n',
#  'significant\n',
#  'differences\n',
#  'were\n',
#  'found\n',
#  'between\n',
#  'the\n',
#  'two\n',
#  'groups\n',
#  'in\n',
#  'the\n',
#  'mode\n',
#  'of\n',
#  'delivery\n',
#  'or\n',
#  'Apgar\n',
#  'scores\n',
#  '\n',
#  'We\n',
#  'conclude\n',
#  'that\n',
#  'to\n',
#  'reduce\n',
#  'the\n',
#  'rate\n',
#  'of\n',
#  'macrosomic\n',
#  'infants\n',
#  'in\n',
#  'gestational\n',
#  'diabetes\n',
#  'cases\n',
#  ',\n',
#  'good\n',
#  'glycemic\n',
#  'control\n',
#  'should\n',
#  'be\n',
#  'initiated\n',
#  'before\n',
#  '34\n',
#  'completed\n',
#  'gestational\n',
#  'weeks\n',
#  '\n',
#  'Our\n',
#  'aim\n',
#  'was\n',
#  'to\n',
#  'investigate\n',
#  'the\n',
#  'contribution\n',
#  'of\n',
#  'certain\n',
#  'antenatally\n',
#  'detectable\n',
#  'markers\n',
#  'leading\n',
#  'to\n',
#  'the\n',
#  'diagnosis\n',
#  'of\n',
#  'trisomic\n',
#  'fetuses\n',
#  'we\n',
#  'observed\n',
#  'over\n',
#  'a\n',
#  'period\n',
#  'of\n',
#  '6\n',
#  'years\n',
#  '\n',
#  'Down\n',
#  'syndrome\n',
#  '(\n',
#  '12\n',
#  'cases\n',
#  ')\n',
#  'and\n',
#  'Edward\n',
#  'syndrome\n',
#  '(\n',
#  '11\n',
#  'cases\n',
#  ')\n',
#  'were\n',
#  'the\n',
#  'most\n',
#  'common\n',
#  'trisomies\n',
#  ',\n',
#  'while\n',
#  '4\n',
#  'cases\n',
#  'of\n',
#  'Patau\n',
#  'syndrome\n',
#  'were\n',
#  'also\n',
#  'diagnosed\n',
#  '\n',
#  'Down\n',
#  'syndrome\n',
#  'fetuses\n',
#  '(\n',
#  '41.7\n',
#  '%\n',
#  ')\n',
#  'had\n',
#  'prenatally\n',
#  'detected\n',
#  'sonographic\n',
#  'anomalies\n',
#  ',\n',
#  '63.6\n',
#  '%\n',
#  'for\n',
#  'Edward\n',
#  'syndrome\n',
#  ',\n',
#  'and\n',
#  'all\n',
#  'fetuses\n',
#  'with\n',
#  'Patau\n',
#  'syndrome\n',
#  '(\n',
#  '4\n',
#  'of\n',
#  '4\n',
#  ')\n',
#  'showed\n',
#  'abnormal\n',
#  'sonographic\n',
#  'signs\n',
#  '\n',
#  'Trisomy\n',
#  '21\n',
#  'presented\n',
#  'with\n',
#  'the\n',
#  'following\n',
#  'features\n',
#  ':\n',
#  'hydramnios\n',
#  ',\n',
#  'complex\n',
#  'malformations\n',
#  ',\n',
#  'pyelectasis\n',
#  ',\n',
#  'and\n',
#  'duodenal\n',
#  'atresia\n',
#  '\n',
#  'Signs\n',
#  'observed\n',
#  'in\n',
#  'fetuses\n',
#  'with\n',
#  'trisomy\n',
#  '13\n',
#  'were\n',
#  ':\n',
#  'hydrocephalus\n',
#  ',\n',
#  'intrauterine\n',
#  'growth\n',
#  'retardation\n',
#  ',\n',
#  'oligoanhydramnios\n',
#  ',\n',
#  'complex\n',
#  'malformations\n',
#  ',\n',
#  'severe\n',
#  'fetal\n',
#  'bradycardia\n',
#  'and\n',
#  'hydronephrosis\n',
#  '\n',
#  'Fifty-three\n',
#  'triplet\n',
#  'pregnancies\n',
#  'between\n',
#  '1986\n',
#  'and\n',
#  '1993\n',
#  'at\n',
#  'The\n',
#  'New\n',
#  'York\n',
#  'Hospital-Cornell\n',
#  'Medical\n',
#  'Center\n',
#  'were\n',
#  'reviewed\n',
#  '\n',
#  'Severe\n',
#  'preeclampsia\n',
#  'was\n',
#  'defined\n',
#  'by\n',
#  'standard\n',
#  'criteria\n',
#  '\n',
#  'Student\n',
#  "'s\n",
#  't-test\n',
#  ',\n',
#  'Fisher\n',
#  'exact\n',
#  'test\n',
#  ',\n',
#  'and\n',
#  'Chi-square\n',
#  'were\n',
#  'used\n',
#  'for\n',
#  'statistical\n',
#  'analysis\n',
#  '\n',
#  'The\n',
#  'rate\n',
#  'of\n',
#  'overall\n',
#  'preeclampsia\n',
#  'was\n',
#  'not\n',
#  'significantly\n',
#  'different\n',
#  'in\n',
#  'the\n',
#  'triplet\n',
#  '18\n',
#  'of\n',
#  '53\n',
#  '(\n',
#  '33.96\n',
#  '%\n',
#  ')\n',
#  'or\n',
#  'twin\n',
#  '12\n',
#  'of\n',
#  '53\n',
#  '(\n',
#  '22.6\n',
#  '%\n',
#  ')\n',
#  'groups\n',
#  '\n',
#  'In\n',
#  'this\n',
#  'retrospective\n',
#  ',\n',
#  'case-controlled\n',
#  'study\n',
#  ',\n',
#  'the\n',
#  'rate\n',
#  'of\n',
#  'severe\n',
#  'pre-eclampsia\n',
#  'was\n',
#  'significantly\n',
#  'increased\n',
#  'in\n',
#  'triplet\n',
#  'gestations\n',
#  'as\n',
#  'compared\n',
#  'to\n',
#  'twins\n',
#  'although\n',
#  'the\n',
#  'overall\n',
#  'rate\n',
#  'of\n',
#  'preeclampsia\n',
#  'was\n',
#  'not\n',
#  '\n',
#  'This\n',
#  'information\n',
#  'may\n',
#  'be\n',
#  'useful\n',
#  'in\n',
#  'counseling\n',
#  'patients\n',
#  'with\n',
#  'high\n',
#  'order\n',
#  'multifetal\n',
#  'gestations\n',
#  '\n',
#  'The\n',
#  'survey\n',
#  'indicated\n',
#  'a\n',
#  'variety\n',
#  'of\n',
#  'thermal\n',
#  'care\n',
#  'styles\n',
#  '\n',
#  'Two\n',
#  'NICUs\n',
#  'preferred\n',
#  'to\n',
#  'admit\n',
#  'infants\n',
#  'to\n',
#  'incubators\n',
#  ',\n',
#  'the\n',
#  'other\n',
#  'three\n',
#  'favoring\n',
#  'radiant\n',
#  'warmers\n',
#  '\n',
#  'These\n',
#  'three\n',
#  'NICUs\n',
#  'moved\n',
#  'infants\n',
#  'from\n',
#  'radiant\n',
#  'warmers\n',
#  'into\n',
#  'incubators\n',
#  'at\n',
#  'significantly\n',
#  'different\n',
#  'mean\n',
#  'ages\n',
#  '\n',
#  'The\n',
#  'audit\n',
#  'demonstrated\n',
#  'inconsistent\n',
#  'use\n',
#  'of\n',
#  'plastic\n',
#  'covers\n',
#  ',\n',
#  'warming\n',
#  'mattresses\n',
#  ',\n',
#  'and\n',
#  'added\n',
#  'humidity\n',
#  'under\n',
#  'radiant\n',
#  'warmers\n',
#  ',\n',
#  'and\n',
#  'discrepancies\n',
#  'between\n',
#  'survey\n',
#  'responses\n',
#  'and\n',
#  'actual\n',
#  'use\n',
#  'within\n',
#  'NICUs\n',
#  '\n',
#  'Inter-NICU\n',
#  'variability\n',
#  'of\n',
#  'thermal\n',
#  'equipment\n',
#  'use\n',
#  'may\n',
#  'complicate\n',
#  'fluid\n',
#  'management\n',
#  '\n',
#  'This\n',
#  'report\n',
#  'describes\n',
#  'a\n',
#  'full-term\n',
#  'newborn\n',
#  'with\n',
#  'massive\n',
#  'fetomaternal\n',
#  'hemorrhage\n',
#  '\n',
#  'Fetal\n',
#  'movements\n',
#  'were\n',
#  'decreased\n',
#  '48\n',
#  'hr\n',
#  'prior\n',
#  'to\n',
#  'delivery\n',
#  '\n',
#  'On\n',
#  'the\n',
#  'day\n',
#  'of\n',
#  'delivery\n',
#  ',\n',
#  'they\n',
#  'were\n',
#  'absent\n',
#  '\n',
#  'The\n',
#  'nonstress\n',
#  'test\n',
#  'was\n',
#  'abnormal\n',
#  'with\n',
#  'low\n',
#  'biophysical\n',
#  'profile\n',
#  'and\n',
#  'decreased\n',
#  'beat-to-beat\n',
#  'variability\n',
#  '\n',
#  'Omphalocele-Exstrophy-Imperforate\n',
#  'anus-Spinal\n',
#  'defects\n',
#  '(\n',
#  'OEIS\n',
#  'complex\n',
#  ')\n',
#  ',\n',
#  'a\n',
#  'combination\n',
#  'of\n',
#  'omphalocele\n',
#  ',\n',
#  'exstrophy\n',
#  'of\n',
#  'the\n',
#  'bladder\n',
#  ',\n',
#  'an\n',
#  'imperforate\n',
#  'anus\n',
#  'and\n',
#  'spinal\n',
#  'defects\n',
#  ',\n',
#  'arises\n',
#  'from\n',
#  'a\n',
#  'single\n',
#  'localized\n',
#  'defect\n',
#  'in\n',
#  'the\n',
#  'early\n',
#  'development\n',
#  'of\n',
#  'the\n',
#  'mesoderm\n',
#  'that\n',
#  'will\n',
#  'later\n',
#  'contribute\n',
#  'to\n',
#  'infraumbilical\n',
#  'mesenchyme\n',
#  ',\n',
#  'cloacal\n',
#  'septum\n',
#  ',\n',
#  'and\n',
#  'caudal\n',
#  'vertebrae\n',
#  '\n',
#  'In\n',
#  'this\n',
#  'report\n',
#  ',\n',
#  'we\n',
#  'document\n',
#  'the\n',
#  'perinatal\n',
#  'features\n',
#  'of\n',
#  'two\n',
#  'cases\n',
#  'of\n',
#  'OEIS\n',
#  'complex\n',
#  'associated\n',
#  'with\n',
#  'meningomyeloceles\n',
#  'and\n',
#  'severe\n',
#  'lower\n',
#  'limb\n',
#  'defects\n',
#  ',\n',
#  'and\n',
#  'discuss\n',
#  'the\n',
#  'prenatal\n',
#  'diagnosis\n',
#  ',\n',
#  'inheritance\n',
#  ',\n',
#  'and\n',
#  'differential\n',
#  'diagnosis\n',
#  'of\n',
#  'this\n',
#  'association\n',
#  'of\n',
#  'malformations\n',
#  '\n',
#  'Although\n',
#  'long-term\n',
#  'survival\n',
#  'can\n',
#  'be\n',
#  'achieved\n',
#  'by\n',
#  'successful\n',
#  'corrective\n',
#  'surgery\n',
#  ',\n',
#  'the\n',
#  'associated\n',
#  'structural\n',
#  'defects\n',
#  'such\n',
#  'as\n',
#  'large\n',
#  'meningomyelocele\n',
#  'and\n',
#  'severe\n',
#  'limb\n',
#  'aplasia\n',
#  'or\n',
#  'hypoplasia\n',
#  ',\n',
#  'as\n',
#  'seen\n',
#  'in\n',
#  'our\n',
#  'patient\n',
#  ',\n',
#  'can\n',
#  'influence\n',
#  'the\n',
#  'patient\n',
#  "'s\n",
#  'quality\n',
#  'of\n',
#  'life\n',
#  '.\n',
#  '\n',
#  'We\n',
#  'would\n',
#  'like\n',
#  'to\n',
#  'emphasize\n',
#  'that\n',
#  'an\n',
#  'accurate\n',
#  'prenatal\n',
#  'diagnosis\n',
#  'of\n',
#  'OEIS\n',
#  'complex\n',
#  'and\n',
#  'associated\n',
#  'malformations\n',
#  'is\n',
#  'important\n',
#  'for\n',
#  'the\n',
#  'detailed\n',
#  'counseling\n',
#  'of\n',
#  'the\n',
#  'family\n',
#  'as\n',
#  'well\n',
#  'as\n',
#  'appropriate\n',
#  'perinatal\n',
#  'management\n',
#  'by\n',
#  ...]

# %% [markdown]
# It seems that the dataset provided is in the form of one word per line.
# We need to pre-process the data to recover the complete sentences and their labels.

# %%
#Checking to see that the number of tokens and number of corresponding labels are same.
print("Number of tokens in training set","\nNo. of words: ",len(train_words),"\nNo. of labels: ",len(train_labels_by_word))
print("\nNumber of tokens in test set","\nNo. of words: ",len(test_words),"\nNo. of labels: ",len(test_labels_by_word))
# Out:
# Number of tokens in training set
# No. of words:  48501
# No. of labels:  48501
#
# Number of tokens in test set
# No. of words:  19674
# No. of labels:  19674

# %%
#Combining tokens belonging to the same sentence. Sentences are separated by "\n" in the dataset.
def convert_to_sentences(dataset):
    sent_list = []
    sent = ""
    for entity in dataset:
        if entity != '\n':
            sent = sent + entity[:-1] + " "       
        else: 
            sent_list.append(sent[:-1])           
            sent = ""
    return sent_list

# %%
#Converting tokens to sentences and individual labels to sequences of corresponding labels.
train_sentences = convert_to_sentences(train_words)
train_labels = convert_to_sentences(train_labels_by_word)
test_sentences = convert_to_sentences(test_words)
test_labels = convert_to_sentences(test_labels_by_word)

# %%
print("First five training sentences and their labels:\n")
for i in range(5):
    print(train_sentences[i],"\n",train_labels[i],"\n")
# Out:
# First five training sentences and their labels:
#
# All live births > or = 23 weeks at the University of Vermont in 1995 ( n = 2395 ) were retrospectively analyzed for delivery route , indication for cesarean , gestational age , parity , and practice group ( to reflect risk status )
#  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
#  O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Abnormal presentation was the most common indication ( 25.6 % , 88 of 344 )
#  O O O O O O O O O O O O O O O
#
# The `` corrected '' cesarean rate ( maternal-fetal medicine and transported patients excluded ) was 12.4 % ( 273 of 2194 ) , and the `` corrected '' primary rate was 9.6 % ( 190 of 1975 )
#  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Arrest of dilation was the most common indication in both `` corrected '' subgroups ( 23.4 and 24.6 % , respectively )
#  O O O O O O O O O O O O O O O O O O O O O O

# %%
print("First five test sentences and their labels:\n")
for i in range(5):
    print(test_sentences[i],"\n",test_labels[i],"\n")
# Out:
# First five test sentences and their labels:
#
# Furthermore , when all deliveries were analyzed , regardless of risk status but limited to gestational age > or = 36 weeks , the rates did not change ( 12.6 % , 280 of 2214 ; primary 9.2 % , 183 of 1994 )
#  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# As the ambient temperature increases , there is an increase in insensible fluid loss and the potential for dehydration
#  O O O O O O O O O O O O O O O O O O O
#
# The daily high temperature ranged from 71 to 104 degrees F and AFI values ranged from 1.7 to 24.7 cm during the study period
#  O O O O O O O O O O O O O O O O O O O O O O O O
#
# There was a significant correlation between the 2- , 3- , and 4-day mean temperature and AFI , with the 4-day mean being the most significant ( r = 0.31 , p & # 60 ; 0.001 )
#  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Fluctuations in ambient temperature are inversely correlated to changes in AFI
#  O O O O O O O O O O O

# %%
# number of sentences in the processed train and test dataset
print("Number of sentences in the train dataset: {}".format(len(train_sentences)))
print("Number of sentences in the test dataset: {}".format(len(test_sentences)))
# Out:
# Number of sentences in the train dataset: 2599
# Number of sentences in the test dataset: 1056

# %%
# number of lines of labels in the processed train and test dataset
print("Number of lines of labels in the train dataset: {}".format(len(train_labels)))
print("Number of lines of labels in the test dataset: {}".format(len(test_labels)))
# Out:
# Number of lines of labels in the train dataset: 2599
# Number of lines of labels in the test dataset: 1056

# %% [markdown]
# #### EDA

# %% [markdown]
# First will explore what are the various concepts present in the dataset. For this, we will use PoS Tagging.
